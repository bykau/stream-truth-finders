# %% [markdown]
# <h1>Proof of problem(Bayesian algorithm)</h1>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sys

# %matplotlib inline

# %%
print 'Python version ' + sys.version
print 'Pandas version ' + pd.__version__
# Out:
# Python version 2.7.10 (default, Oct 23 2015, 18:05:06)
# [GCC 4.2.1 Compatible Apple LLVM 7.0.0 (clang-700.0.59.5)]
# Pandas version 0.17.1

# %%
st = pd.read_csv('proof_prob_output.csv')

# %%
plt.plot(st['number_of_swaps'], st['dist_metric_mean'], 'bo-', label='Bayesian algorithm')
plt.errorbar(st['number_of_swaps'], st['dist_metric_mean'], yerr=st['dist_metric_std'])
plt.xlabel('number_of_swaps')
plt.ylabel('dist_metric_mean')
